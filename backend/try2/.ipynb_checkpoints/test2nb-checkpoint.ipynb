# %%
from langchain_community.llms import HuggingFaceEndpoint

# %%
# from getpass import getpass
from dotenv import load_dotenv

# %%
import os

# %%
load_dotenv()
# Out:
# True

# %%
HUGGINGFACEHUB_API_TOKEN = os.getenv("HUGGINGFACEHUB_API_TOKEN")

# %%
from langchain.chains import LLMChain
from langchain_core.prompts import PromptTemplate

# question = "Who won the FIFA World Cup in the year 1994? "

# template = """Question: {question}

# Answer: Let's think step by step."""

# prompt = PromptTemplate.from_template(template)

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.2"

llm = HuggingFaceEndpoint(
    repo_id=repo_id, max_length=8000, temperature=0.5, token=HUGGINGFACEHUB_API_TOKEN
)
# llm_chain = LLMChain(prompt=prompt, llm=llm)
# print(llm_chain.run(question))
# Out:
# WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to C:\Users\Devangana\.cache\huggingface\token
# Login successful

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

from langchain_pinecone import PineconeVectorStore

# %%
loader = PyPDFLoader("Modi-Ki-Guarantee-Sankalp-Patra-English_2.pdf")
data = loader.load()
print(data)
# Out:
# [Document(page_content='1\n', metadata={'source': 'Modi-Ki-Guarantee-Sankalp-Patra-English_2.pdf', 'page': 0}), Document(page_content='2\n', metadata={'source': 'Modi-Ki-Guarantee-Sankalp-Patra-English_2.pdf', 'page': 1}), Document(page_content='CONTENTSTABLE\nOF \nShri Narendra Modi’s Letter to the Nation 01\nPresident’s Note 03\nSankalp Patra Note 04\n10 Years of Good Governance and Vikas 05\nModi Ki Guarantee for Garib Parivar Jan 11\nModi Ki Guarantee for Middle-Class Parivar Jan 13\nModi ki Guarantee for Nari Shakti 15\nModi ki Guarantee for Young Citizens 17\nModi ki Guarantee for Senior Citizens 20\nModi ki Guarantee for Kisan Samman 22\nModi ki Guarantee for Fishermen Families 26\nModi ki Guarantee for Shramik Samman 28\nModi ki Guarantee for MSME, Small Traders and Vishwakarmas 30\nModi ki Guarantee for Sabka Saath Sabka Vikas 32\nModi ki Guarantee for Vishwa Bandhu Bharat 35\nModi ki Guarantee for Surakshit Bharat 38\nModi ki Guarantee for Prosperous Bharat 40\nModi ki Guarantee for Global Manufacturing Hub 42\nModi ki Guarantee for World-Class Infrastructure 45\nModi ki Guarantee for Ease of Living in Cities 50\nModi ki Guarantee for Virasat Bhi, Vikas Bhi 52\nModi Ki Guarantee for Good Governance 54\nModi ki Guarantee for Swastha Bharat 57\nModi ki Guarantee for Quality Education 59\nModi ki Guarantee for Sports Development 61\nModi Ki Guarantee for Balanced Regional Development 63\nModi ki Guarantee for Technology and Innovations 65\nModi ki Guarantee for Sustainable Bharat 67\n', metadata={'source': 'Modi-Ki-Guarantee-Sankalp-Patra-English_2.pdf', 'page': 2}), Document(page_content='Shri Narendra Modi’s \nLetter to the Nation\nMere Priya Parivarjan,\nIt has been a decade since you blessed Bharatiya Janata Party with the responsibility of serving you. The \nfact that you blessed me to be your Pradhan Sevak at an extremely important time in the history of our \ncountry inspires me to work ever harder. In the last ten years, every moment of our time and every ounce of \nour energy has been dedicated for the people’s welfare.\nWith your trust and support, the nation has seen a massive transformation over the last ten years. While \ndevelopment attained an unprecedented speed and scale, a signiﬁcant transformation has also happened in \nterms of mindset.\nToday, our youth are speaking of creating Viksit Bharat by 2047 as a goal that is attainable, as a milestone \nthat will certainly be reached. The nation is conﬁdent on its journey of becoming self-reliant (Aatmanirbhar). \nThis is a big change from the atmosphere of desperation and frustration that the nation had experienced in \nthe decade prior to 2014 due to the corruption, policy paralysis and misrule by the government of those \ntimes.\nWe have gone from a nation that was in the ‘Fragile Five’ to a nation that is one of the top 5 economies of \nthe world. The most important facet of this progress is that the fruits of development reached everyone, \nespecially those who needed it the most. The mantra of Sabka Saath, Sabka Vikas, Sabka Vishwas, Sabka \nPrayas has guided our actions.\nThe nation’s growth has been powered by the victory of 25 crore people in the battle against poverty. These \nare people who had suffered decades of deprivation of even basic necessities. Today, not only are they \nbeneﬁting from our saturation approach in basic needs like bank accounts, gas connections, toilets, water, \nelectricity, etc, but they are also being empowered with new-age facilities like optic ﬁbre connections, digital \nsolutions, drones, etc.\nThe nation’s growth has come from the drastic socio-economic transformation seen in the lives of women, \nfarmers, ﬁsherfolks, street vendors, small entrepreneurs, SC, ST and OBC communities. They are being \ndirectly empowered through the power of technology such as the JAM trinity.\nFarmers have been a backbone of our nation’s progress. Whether it is historic MSP hikes, massive rise in \nprocurement or making fertilisers avai ...

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=10000, chunk_overlap=20)

text_chunks = text_splitter.split_documents(data)

len(text_chunks)
# Out:
# 77

# %%
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Retrieve Pinecone API key from environment variable
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")

# Define Pinecone index name
index_name = "myindex"

# Initialize Pinecone vector store
vector_store = PineconeVectorStore.from_documents(text_chunks, index_name=index_name, embedding=embeddings)

# Add documents to Pinecone index
# vector_store.add_documents(text_chunks)

# since pinecone is being used for vector store
# vector_store = FAISS.from_documents(text_chunks, embedding=embeddings)
# Out:
# C:\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# PineconeConfigurationError                Traceback (most recent call last)
# Cell In[9], line 7
#       4 index_name = "myindex"
#       6 # Initialize Pinecone vector store
# ----> 7 vector_store = PineconeVectorStore.from_documents(text_chunks, index_name=index_name, embedding=embeddings)
#       9 # Add documents to Pinecone index
#      10 # vector_store.add_documents(text_chunks)
#      11
#      12 # since pinecone is being used for vector store
#      13 # vector_store = FAISS.from_documents(text_chunks, embedding=embeddings)
#
# File C:\Python312\Lib\site-packages\langchain_core\vectorstores.py:550, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     548 texts = [d.page_content for d in documents]
#     549 metadatas = [d.metadata for d in documents]
# --> 550 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File C:\Python312\Lib\site-packages\langchain_pinecone\vectorstores.py:438, in PineconeVectorStore.from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, **kwargs)
#     395 @classmethod
#     396 def from_texts(
#     397     cls,
#    (...)
#     409     **kwargs: Any,
#     410 ) -> PineconeVectorStore:
#     411     """Construct Pinecone wrapper from raw documents.
#     412
#     413     This is a user friendly interface that:
#    (...)
#     436             )
#     437     """
# --> 438     pinecone_index = cls.get_pinecone_index(index_name, pool_threads)
#     439     pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
#     441     pinecone.add_texts(
#     442         texts,
#     443         metadatas=metadatas,
#    (...)
#     448         **(upsert_kwargs or {}),
#     449     )
#
# File C:\Python312\Lib\site-packages\langchain_pinecone\vectorstores.py:374, in PineconeVectorStore.get_pinecone_index(cls, index_name, pool_threads, pinecone_api_key)
#     366 """Return a Pinecone Index instance.
#     367
#     368 Args:
#    (...)
#     371 Returns:
#     372     Pinecone Index instance."""
#     373 _pinecone_api_key = pinecone_api_key or os.environ.get("PINECONE_API_KEY") or ""
# --> 374 client = PineconeClient(
#     375     api_key=_pinecone_api_key, pool_threads=pool_threads, source_tag="langchain"
#     376 )
#     377 indexes = client.list_indexes()
#     378 index_names = [i.name for i in indexes.index_list["indexes"]]
#
# File C:\Python312\Lib\site-packages\pinecone\control\pinecone.py:185, in Pinecone.__init__(self, api_key, host, proxy_url, proxy_headers, ssl_ca_certs, ssl_verify, config, additional_headers, pool_threads, index_api, **kwargs)
#     183         self.config = config
#     184 else:
# --> 185     self.config = PineconeConfig.build(
#     186         api_key=api_key,
#     187         host=host,
#     188         additional_headers=additional_headers,
#     189         proxy_url=proxy_url,
#     190         proxy_headers=proxy_headers,
#     191         ssl_ca_certs=ssl_ca_certs,
#     192         ssl_verify=ssl_verify,
#     193         **kwargs
#     194     )
#     196 if kwargs.get("openapi_config", None):
#     197     warnings.warn("Passing openapi_config is deprecated and will be removed in a future release. Please pass settings such as proxy_url, proxy_headers, ssl_ca_certs, and ssl_verify directly to the Pinecone constructor as keyword arguments. See the README at https://github.com/pinecone-io/pinecone-python-client for examples.", DeprecationWarning)
#
# File C:\Python312\Lib\site-packages\pinecone\config\pinecone_config.py:24, in PineconeConfig.build(api_key, host, additional_headers, **kwargs)
#      21   except Exception as e:
#      22     logger.warn(f'Ignoring PINECONE_ADDITIONAL_HEADERS: {e}')
# ---> 24 return ConfigBuilder.build(api_key=api_key, host=host, additional_headers=additional_headers, **kwargs)
#
# File C:\Python312\Lib\site-packages\pinecone\config\config.py:54, in ConfigBuilder.build(api_key, host, proxy_url, proxy_headers, ssl_ca_certs, ssl_verify, additional_headers, **kwargs)
#      51 source_tag = kwargs.pop(SOURCE_TAG, None)
#      53 if not api_key:
# ---> 54     raise PineconeConfigurationError("You haven't specified an Api-Key.")
#      55 if not host:
#      56     raise PineconeConfigurationError("You haven't specified a host.")
#
# PineconeConfigurationError: You haven't specified an Api-Key.

# %%
# Answer: Let's think step by step."""
# system_prompt = (
#     "Use the given context to answer the question. "
#     "If you don't know the answer, say you don't know. "
#     "Use three sentence maximum and keep the answer concise. "
#     "Context: {context}"
# )
# prompt = ChatPromptTemplate.from_messages(
#     [
#         ("system", system_prompt),
#         ("human", "{input}"),
#     ]
# )

# %%
query = "what is the man to women ratio?"

# %%
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=vector_store.as_retriever(search_kwargs={"k": 2}))
result = qa.invoke(query)
print(result)
# Out:
# {'query': 'what is the man to women ratio?', 'result': ' The man to women ratio at AlwaysFirst is 73:27.'}
